# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# copy & write is for kaftar group in data days challenge
ad_csv = pd.read_csv('/content/drive/My Drive/Data days final challenge/ad.csv')
ad_title_csv = pd.read_csv('/content/drive/My Drive/Data days final challenge/ad_title.csv')
ad_images_csv = pd.read_csv('/content/drive/My Drive/Data days final challenge/ad_image.csv')

# page_csv = pd.read_csv('/content/drive/My Drive/Data days final challenge/page.csv')

event_csv = pd.read_csv('/content/drive/My Drive/Data days final challenge/event.csv')

# should train module on this 
click_train = pd.read_csv('/content/drive/My Drive/Data days final challenge/click_train.csv')

# %% [markdown]
# خلاصه ای از داده های داده شده

# %%
print(ad_csv.head())
print(ad_csv.shape)
# Out:
#    adId  campaignId  advertiserId
# 0  7867        5918          8414
# 1  7866        5918          8414
# 2  7865        5918          8414
# 3  7863        8343          8414
# 4  7862        8343          8414
# (3256, 3)

# %%
print(ad_title_csv.head())
print(ad_title_csv.shape)
# Out:
#    adId  wordId
# 0     6      24
# 1     6      25
# 2     6      26
# 3     6      27
# 4     6      28
# (18122, 2)

# %%
# هر تبلیغ یک عکس داره که فعلا بهش کاری نداریم
print(ad_images_csv.tail())
print(ad_images_csv.shape)
# Out:
#       adId                                      imageFeatures
# 3251    13  [0.14816689491271973, 0.04346756637096405, 1.3...
# 3252    11  [0.04297146946191788, 0.01642996445298195, 0.0...
# 3253     8  [0.15623298287391663, 0.00098716514185071, 0.0...
# 3254     7  [0.10627733916044235, 0.08754178136587143, 3.3...
# 3255     6  [0.0, 0.0, 0.04975997656583786, 0.407063782215...
# (3256, 2)

# %%
print(click_train.head())
# Out:
#    displayId  adId  clicked
# 0    1210227  7182        0
# 1    1210227  7125        0
# 2    1210227  7181        0
# 3    1210227   535        0
# 4    1210227  7174        1
